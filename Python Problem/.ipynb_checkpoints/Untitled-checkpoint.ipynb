# %%
import tweepy 
import json

# %%
#Keys, secret keys and access tokens 
consumer_key = ''
consumer_secret = ''
access_token_key = ''
access_token_secret = ''

# %%
def get_tweets_Json(username): 
    auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
    auth.set_access_token(access_token_key, access_token_secret)
    api = tweepy.API(auth)
    tweets = api.user_timeline(screen_name=username,tweet_mode="extended", include_entities=True, count=100)
    json_tweets = [tweet._json for tweet in tweets]
    with open('Json_Tweet_File.txt', 'wt') as outfile:
       json.dump(json_tweets, outfile)        
    return 'Json_Tweet_File.txt'

# %%
def get_tweet(tweets_file_name): 
    with open(tweets_file_name) as json_file:  
        tweets = json.load(json_file)
        for tweet in tweets:
            count = 0
            try:
                print("Retweet Text: ",tweet['retweeted_status']['full_text'])
            except:
                print("Tweet Text: ",tweet['full_text'])
            print("")
            print("Date: ",tweet['created_at'])
            print("Favorite Count: ",tweet['favorite_count'])
            print("Retweet Count: ",tweet['retweet_count'])
            try:
                try:
                    for x in tweet['retweeted_status']['extended_entities']['media']:
                        if x['type'] == 'photo':
                            count = count+1
                except:
                    for x in tweet['extended_entities']['media']:
                        if x['type'] == 'photo':
                            count = count+1
            except:
                pass
            if count is 0:
                print("Number of Images: None")
            else:
                print("Number of Images: ",count)
            print("------------------------------------------------------------------------------------------------")

# %%
tweets_file_name = get_tweets_Json('midasIIITD')

# %%
get_tweet(tweets_file_name)
# Out:
# Retweet Text:  We are delighted to share that IIIT-Delhi is ranked 55 by NIRF this year. We have moved up by 11 positions compared to the previous ranking.
# We take this opportunity to thank the faculty, officers, students, alumni, collaborators, and well-wishers for this achievement. https://t.co/FealgVAQO2
#
# Date:  Tue Apr 09 16:45:07 +0000 2019
# Favorite Count:  0
# Retweet Count:  9
# Number of Images:  1
# ------------------------------------------------------------------------------------------------
# Retweet Text:  Professor Jelani Nelson founded AddisCoder, a program that teaches students in Ethiopia how to code https://t.co/0sM06p4qxw
#
# Date:  Tue Apr 09 05:04:27 +0000 2019
# Favorite Count:  0
# Retweet Count:  35
# Number of Images: None
# ------------------------------------------------------------------------------------------------
# Retweet Text:  For anyone interested in submitting to EMNLP 2019, the anonymity period begins in less two weeks, on April 21.
# https://t.co/dOfVWlL55u https://t.co/wwQiFZNuBa
#
# Date:  Tue Apr 09 05:04:11 +0000 2019
# Favorite Count:  0
# Retweet Count:  13
# Number of Images:  1
# ------------------------------------------------------------------------------------------------
# Retweet Text:  Announcing the 2019 MediaEval multimedia tasks: https://t.co/V6NMt1vaNV Participation is open for anyone who is interested. Registration starts soon. @sigmm @ACMMM19
#
# Date:  Mon Apr 08 19:38:09 +0000 2019
# Favorite Count:  0
# Retweet Count:  15
# Number of Images: None
# ------------------------------------------------------------------------------------------------
# Tweet Text:  Many Congratulations to @midasIIITD student, Shagun Uppal @shagunuppls, on getting selected for the summer internship in the BRAIN lab at Singapore University of Technology &amp; Design @sutdsg, Singapore.
# We wish her the best luck for the internship.
#
# #MIDAS #StudentAchievement https://t.co/snX2GkzvQg
#
# Date:  Mon Apr 08 07:08:12 +0000 2019
# Favorite Count:  16
# Retweet Count:  2
# Number of Images:  1
# ------------------------------------------------------------------------------------------------
# Tweet Text:  @midasIIITD thanks all students who have appeared for the interview yesterday. We will announce the interview results for MIDAS internship latest by 14th April 2019. Sorry for the delay since we are carefully evaluating all applications that we have received for the internship. https://t.co/FANz5vImwU
#
# Date:  Mon Apr 08 03:27:42 +0000 2019
# Favorite Count:  5
# Retweet Count:  0
# Number of Images:  1
# ------------------------------------------------------------------------------------------------
# Tweet Text:  @himanchalchandr Meanwhile, complete CV/NLP task first.
#
# Date:  Sun Apr 07 14:17:29 +0000 2019
# Favorite Count:  0
# Retweet Count:  0
# Number of Images: None
# ------------------------------------------------------------------------------------------------
# Tweet Text:  @sayangdipto123 Submit as per the guideline again.
#
# Date:  Sun Apr 07 14:17:09 +0000 2019
# Favorite Count:  0
# Retweet Count:  0
# Number of Images: None
# ------------------------------------------------------------------------------------------------
# Tweet Text:  We request all students whose interview are scheduled today to join at the time given to them and not before or after. We have other interviews scheduled which will be affected.
# Thanks much.
#
# Date:  Sun Apr 07 11:43:24 +0000 2019
# Favorite Count:  1
# Retweet Count:  1
# Number of Images: None
# ------------------------------------------------------------------------------------------------
# Tweet Text:  Other queries: "none of the Tweeter Apis give the correct count of favorites tested for most of them, all give the wrong count. same is true for retweet. this mostly happens if the no. of likes, retweet is very large. So, what shld be done?"
# Ans: Just use the count given by API.
#
# Date:  Sun Apr 07 06:55:19 +0000 2019
# Favorite Count:  5
# Retweet Count:  2
# Number of Images: None
# ------------------------------------------------------------------------------------------------
# Tweet Text:  Other queries: "do we have to make two different repositories on Github as "Python Problem" and "CV Problem". Or we have to make a single repository named "root" and upload our code in that?"
# And: Have one repository of any name which has two folders. One python and other cv/nlp
#
# Date:  Sun Apr 07 06:53:38 +0000 2019
# Favorite Count:  4
# Retweet Count:  1
# Number of Images: None
# ------------------------------------------------------------------------------------------------
# Tweet Text:  Other queries: "If using Twitter api, it does not include any information about images in the response objects sent, so how do we retrieve the image info as requested?"
# Ans: U have to use twitter api or wrappers based on it like tweepy.
# Twitter API does provide image information.
#
# Date:  Sun Apr 07 05:32:27 +0000 2019
# Favorite Count:  6
# Retweet Count:  1
# Number of Images: None
# ------------------------------------------------------------------------------------------------
# Tweet Text:  Response to some queries asked by students on @midasIIITD task.
# What does the line "dump the responses into JSONlines file" mean?
# It means you have to dump the response into a jsonlines file. jsonlines is a file extension more popularly know as .jsonl
# #MIDAS #Research #Internship
#
# Date:  Sun Apr 07 05:29:40 +0000 2019
# Favorite Count:  7
# Retweet Count:  1
# Number of Images: None
# ------------------------------------------------------------------------------------------------
# Retweet Text:  Top 8 #Free Must-Read #Books on #DeepLearning #KDN https://t.co/1DtlN91Yjj
#
# Date:  Sat Apr 06 17:11:29 +0000 2019
# Favorite Count:  0
# Retweet Count:  2
# Number of Images: None
# ------------------------------------------------------------------------------------------------
# Tweet Text:  @nupur_baghel @PennDATS Congratulation @nupur_baghel on getting admit from @PennDATS.
# She got 5/10 acceptance. She has worked at @midasIIITD on the #kikichallenge problem. We are glad to know that it inspired her to pursue further research. We wish her a great success ahead.
# #MSc #DataScience #UPenn https://t.co/2daLOHGPBU
#
# Date:  Sat Apr 06 16:43:27 +0000 2019
# Favorite Count:  18
# Retweet Count:  3
# Number of Images:  1
# ------------------------------------------------------------------------------------------------
# Tweet Text:  We have emailed the task details to all candidates who have applied to @midasIIITD internship through IIITD portal. Kindly check your spam folder if you have not received the email. We will evaluate all solutions received until April 10 midnight and announce results by April 14.
#
# Date:  Fri Apr 05 16:08:37 +0000 2019
# Favorite Count:  11
# Retweet Count:  1
# Number of Images: None
# ------------------------------------------------------------------------------------------------
# Retweet Text:  Our NAACL paper on polarization in language on Twitter surrounding mass shootings is up on arXiv! https://t.co/g7wiegXxDg
# This is the first lead-author paper from Dora Demszky; she put a huge amount of work into it and I think it turned out extremely well.
#
# Date:  Fri Apr 05 04:05:11 +0000 2019
# Favorite Count:  0
# Retweet Count:  16
# Number of Images: None
# ------------------------------------------------------------------------------------------------
# Retweet Text:  Effective Transfer Learning For NLP https://t.co/Z1m0AzlfVv https://t.co/ccX4Uhxjn8
#
# Date:  Fri Apr 05 04:04:43 +0000 2019
# Favorite Count:  0
# Retweet Count:  11
# Number of Images:  1
# ------------------------------------------------------------------------------------------------
# Retweet Text:  What’s new in @Stanford CS224N Natural Language Processing with Deep Learning for 2019? Question answering—1D CNNs—subword models—contextual word representations—transformers—generation—bias. YT playlist https://t.co/gFwwXJqYuQ – CS224N online hub https://t.co/HTnMzCAjS3 #NLProc https://t.co/rZKQvfUhiF
#
# Date:  Wed Apr 03 18:31:53 +0000 2019
# Favorite Count:  0
# Retweet Count:  59
# Number of Images:  1
# ------------------------------------------------------------------------------------------------
# Retweet Text:  Today we're releasing a large-scale extendable dataset of mathematical questions, for training (and evaluating the abilities of) neural models that can reason algebraically.
#
# Paper: https://t.co/D8g477gcQ4
# Code and data: https://t.co/QvR2WkK7j2 https://t.co/EWqNqaOUd5
#
# Date:  Wed Apr 03 17:04:32 +0000 2019
# Favorite Count:  0
# Retweet Count:  871
# Number of Images:  1
# ------------------------------------------------------------------------------------------------
# Retweet Text:  Congratulations Jitendra Malik !
#
# Awards are raining on FAIRies these days... https://t.co/1WNcSeQLZe
#
# Date:  Wed Apr 03 09:03:40 +0000 2019
# Favorite Count:  0
# Retweet Count:  16
# Number of Images: None
# ------------------------------------------------------------------------------------------------
# Retweet Text:  Another chance to take admission in the Ph.D. program in IIIT Delhi.
# Admissions open for Ph.D. program mathematics
#
# Log on to know more and apply: https://t.co/KgrmqscaIm
#
# #Admissions
#
# Date:  Wed Apr 03 07:46:02 +0000 2019
# Favorite Count:  0
# Retweet Count:  4
# Number of Images: None
# ------------------------------------------------------------------------------------------------
# Tweet Text:  Dear @midasIIITD internship candidates who have submitted their solutions to the task, we have sent you an email regarding your results.
#
# Students who have applied through @IIITDelhi, you will soon be contacted on the internship task.
#
# #MIDAS #Summer #Research #Internship
#
# Date:  Tue Apr 02 04:20:13 +0000 2019
# Favorite Count:  8
# Retweet Count:  1
# Number of Images: None
# ------------------------------------------------------------------------------------------------
# Tweet Text:  Looking forward to your paper submission to @IEEEBigMM19.
#
# Important Dates:
# Regular Paper: 11:59pm PST, May 10, 2019
# Short Paper: 11:59pm PST, May 10, 2019
# Industry Paper: 11:59pm PST, May 10, 2019
# Demonstration Paper: 11:59pm PST, May 10, 2019
#
# Contact TPC @RatnRajiv
#
# Date:  Tue Apr 02 02:44:54 +0000 2019
# Favorite Count:  5
# Retweet Count:  1
# Number of Images: None
# ------------------------------------------------------------------------------------------------
# Retweet Text:  Reproducibility in multimedia research in @sigmm records https://t.co/hOyMxtmy7A Plus reminder to past-year authors: Today 1 April AOE is the day to submit your repro abstract for @ACMMM19
#
# Date:  Tue Apr 02 02:35:44 +0000 2019
# Favorite Count:  0
# Retweet Count:  7
# Number of Images: None
# ------------------------------------------------------------------------------------------------
# Tweet Text:  Online application for https://t.co/DJFDrQsHZP. Admission 2019 at @IIITDelhi has been open
#
# Log on to know more and apply: https://t.co/w7d2UMTVh7
#
# Last Date: 18th April 2019
#
# #MTech #IIITD #Admission
#
# Date:  Mon Apr 01 06:53:08 +0000 2019
# Favorite Count:  7
# Retweet Count:  2
# Number of Images: None
# ------------------------------------------------------------------------------------------------
# Retweet Text:  A final reminder of the Reproducibility Track: Authors of 2017 and 2018 papers are invited to submit a short reproducibility paper: ACM MM 2019 will feature a reproducibility poster session https://t.co/q2IFt9lTac https://t.co/zUJEmH6HAd
#
# Date:  Sun Mar 31 10:21:24 +0000 2019
# Favorite Count:  0
# Retweet Count:  10
# Number of Images:  1
# ------------------------------------------------------------------------------------------------
# Retweet Text:  Thanks for the support and help @debanjanbhucs @RatnRajiv and @midasIIITD. It was a great learning experience! Glad to be part of the team. https://t.co/g45tIJQ18s
#
# Date:  Fri Mar 29 19:43:24 +0000 2019
# Favorite Count:  0
# Retweet Count:  2
# Number of Images: None
# ------------------------------------------------------------------------------------------------
# Tweet Text:  Since SemEval-2019 will be held June 6-7, 2019 in Minneapolis, USA, collocated with NAACL-HLT 2019, it will great students for @midasIIITD students to attend the conference and learn from worldclass researchers. +@aggarwal_kartik
#
# Date:  Fri Mar 29 17:16:40 +0000 2019
# Favorite Count:  9
# Retweet Count:  1
# Number of Images: None
# ------------------------------------------------------------------------------------------------
# Tweet Text:  +@aggarwal_kartik.
# Congrats! Wish you many more success.
#
# Date:  Fri Mar 29 17:04:30 +0000 2019
# Favorite Count:  2
# Retweet Count:  0
# Number of Images: None
# ------------------------------------------------------------------------------------------------
# Retweet Text:  Our work (@midasIIITD ) accepted at SemEval 2019 at @NAACLHLT : "MIDAS at SemEval-2019 Task 9: Suggestion Mining from Online Reviews using ULMFiT".
# We ranked 10th on the leaderboard. Code available at: https://t.co/Yuqbc3WjnB
#
# Date:  Fri Mar 29 17:03:29 +0000 2019
# Favorite Count:  0
# Retweet Count:  1
# Number of Images: None
# ------------------------------------------------------------------------------------------------
# Tweet Text:  Congratulations! @midasIIITD team, @isarth23 @LaibaMehnaz @Simcyy @debanjanbhucs @RatnRajiv @the_dhumketu for getting two papers accepted at SemEval 2019.
# Many thanks to our collaborators Haimin and Karan for their help.
#
# #NLP #Research #SocialMedia #Analytics #DeepLearning
#
# Date:  Fri Mar 29 17:02:24 +0000 2019
# Favorite Count:  9
# Retweet Count:  1
# Number of Images: None
# ------------------------------------------------------------------------------------------------
# Tweet Text:  @EEMLcommunity @radamihalcea too many deadlines coming, @ACMMM19 @IEEEBigMM19 @EEMLcommunity
#
# Date:  Fri Mar 29 05:35:22 +0000 2019
# Favorite Count:  0
# Retweet Count:  0
# Number of Images: None
# ------------------------------------------------------------------------------------------------
# Retweet Text:  CS224N Natural Language Processing with Deep Learning 2019 @Stanford course videos by @chrmanning, @abigail_e_see &amp; guests are now mostly available (16 of 20). Big update from 2017. YouTube playlist: https://t.co/gFwwXJqYuQ – new CS224N online hub: https://t.co/HTnMzCAjS3 #NLProc https://t.co/3S9iDX2e2o
#
# Date:  Thu Mar 28 16:55:01 +0000 2019
# Favorite Count:  0
# Retweet Count:  719
# Number of Images:  1
# ------------------------------------------------------------------------------------------------
# Retweet Text:  Learn PyTorch by running on Google GPUs for free. https://t.co/pt038TMnWR
#
# Date:  Thu Mar 28 16:54:37 +0000 2019
# Favorite Count:  0
# Retweet Count:  156
# Number of Images: None
# ------------------------------------------------------------------------------------------------
# Tweet Text:  Dr. Vineeth N Balasubramanian will present a Talk on "Towards Explainable Deep Learning: Adding Why to What" on 28th Mar 2019 (Thursday). Please find the details below:
#
# Time: 4 PM
# Venue: A007, R&amp;D Block
#
# #ResearchTalk #Multimedia #Explainable #DeepLearning https://t.co/Cyz7F5f29I
#
# Date:  Wed Mar 27 16:09:09 +0000 2019
# Favorite Count:  4
# Retweet Count:  1
# Number of Images:  1
# ------------------------------------------------------------------------------------------------
# Retweet Text:  I am extremely honored to be the recipient of the 2018 ACM A.M. Turing Award, and absolutely delighted to be sharing it with my friends and colleagues Geoffrey Hinton and Yoshua Bengio.
#
# NYT:... https://t.co/BIMuqDcZj0
#
# Date:  Wed Mar 27 11:53:40 +0000 2019
# Favorite Count:  0
# Retweet Count:  1545
# Number of Images: None
# ------------------------------------------------------------------------------------------------
# Tweet Text:  Thanks to all shortlisted candidates for submitting their solutions for @midasIIITD internship task 2019. We are currently evaluating all solutions and will try to get back to all candidates in a week time.
#
# #MIDAS #Summer #Research #Internship
#
# Date:  Tue Mar 26 18:12:27 +0000 2019
# Favorite Count:  5
# Retweet Count:  1
# Number of Images: None
# ------------------------------------------------------------------------------------------------
# Tweet Text:  @IEEEBigMM19 @ACMMM19 and 6 days left for workshop proposal in @IEEEBigMM19.
#
# Contact @cchatto for any query.
#
# Date:  Tue Mar 26 05:54:49 +0000 2019
# Favorite Count:  2
# Retweet Count:  0
# Number of Images: None
# ------------------------------------------------------------------------------------------------
# Retweet Text:  Hurry Up!
# 6 Days left for Abstract Submission in @ACMMM19
# 45 Days left for Regular Paper Submission in @IEEEBigMM19 .
#
# Hectic time ahead or Multimedia Researchers :)
#
# Date:  Tue Mar 26 05:50:10 +0000 2019
# Favorite Count:  0
# Retweet Count:  3
# Number of Images: None
# ------------------------------------------------------------------------------------------------
# Tweet Text:  Congratulations @midasIIITD students Simra Shahid @Simcyy and Nilay Shrivastava @NilayShri on getting selected for a research internship at Adobe in this summer.
#
# #MIDAS #Achievment #Research #Summer #Internship https://t.co/WdF663EB5y
#
# Date:  Mon Mar 25 13:01:57 +0000 2019
# Favorite Count:  18
# Retweet Count:  1
# Number of Images:  2
# ------------------------------------------------------------------------------------------------
# Tweet Text:  The last date for submitting a solution for the @midasIIITD internship task is 26th March midnight. We will not accept solutions submitted after the deadline.
# Thus, if you have not submitted your solution yet then kindly do so before the deadline.
# #Summer #Research #Internship
#
# Date:  Sun Mar 24 18:44:01 +0000 2019
# Favorite Count:  8
# Retweet Count:  3
# Number of Images: None
# ------------------------------------------------------------------------------------------------
# Retweet Text:  @IIITDelhi invites application from Foreign Nationals/PIOs/NRIs/OCIs for admission to its https://t.co/u6kIuhIrGM and https://t.co/Q0ibR1xaDl Programs through IIIT-Delhi admission process for AY 2019-20. Visit Website for more information : https://t.co/CGWqrughDw https://t.co/c2o3593dbR
#
# Date:  Sun Mar 24 18:26:02 +0000 2019
# Favorite Count:  0
# Retweet Count:  4
# Number of Images:  1
# ------------------------------------------------------------------------------------------------
# Tweet Text:  One more week is left to submit the workshop proposal to @IEEEBigMM19.
# Looking forward to your submission. For any query, contact workshop co-chair Dr. Chiranjoy Chattopadhyay @cchatto or TPC co-chair @RatnRajiv
#
# Date:  Sun Mar 24 11:34:27 +0000 2019
# Favorite Count:  4
# Retweet Count:  0
# Number of Images: None
# ------------------------------------------------------------------------------------------------
# Retweet Text:  We are honored to have Dr. Chang Wen Chen (Chinese University Hong Kong @CUHKofficial ) and Dr. Roger Zimmermann (National University Singapore @NUSingapore ) as our General co-chairs.
#
# Date:  Sun Mar 24 06:23:37 +0000 2019
# Favorite Count:  0
# Retweet Count:  5
# Number of Images: None
# ------------------------------------------------------------------------------------------------
# Retweet Text:  Distinguished researchers Dr. Rajiv Ratn Shah @RatnRajiv (@IIITDelhi , @midasIIITD ), Dr. Jianquan Liu (NEC Japan) and Dr. Vivek Singh (Rutgers University @RutgersU ) will be our technical program co-chairs.
#
# Date:  Sun Mar 24 06:23:14 +0000 2019
# Favorite Count:  0
# Retweet Count:  3
# Number of Images: None
# ------------------------------------------------------------------------------------------------
# Tweet Text:  @IEEEBigMM19 is also available on Facebook now.
# LIKE its Facebook page https://t.co/B3Q0zmmzXb  to get the regular updates.
# Check more details at https://t.co/w9ZymoPisk
#
# #IEEE #BigMM19 #Big #Multimedia #Singapore
#
# Date:  Wed Mar 20 08:19:24 +0000 2019
# Favorite Count:  1
# Retweet Count:  1
# Number of Images: None
# ------------------------------------------------------------------------------------------------
# Retweet Text:  BigMM 2019 : IEEE BigMM 2019 – Call for Workshop Proposals
#
# https://t.co/I4vqf8FE6K …
# When: Sep 11, 2019 - Sep 13, 2019
# Where: Singapore
# Submission Deadline: Apr 1, 2019
# Notification Due: Apr 10, 2019
#
# #IEEE #BigData #Singapore #Multimedia
#
# Date:  Wed Mar 20 02:40:07 +0000 2019
# Favorite Count:  0
# Retweet Count:  5
# Number of Images: None
# ------------------------------------------------------------------------------------------------
# Tweet Text:  BigMM 2019 : IEEE BigMM 2019 – Call for Workshop Proposals
#
# https://t.co/oUq2G0UgKN
#
# When: Sep 11, 2019 - Sep 13, 2019
# Where: Singapore
# Submission Deadline: Apr 1, 2019
# Notification Due: Apr 10, 2019
#
# #IEEE #BigMM #Workshop #Proposal #Singapore #Multimedia
#
# Date:  Mon Mar 18 02:27:47 +0000 2019
# Favorite Count:  6
# Retweet Count:  3
# Number of Images: None
# ------------------------------------------------------------------------------------------------
# Tweet Text:  Congratulations @midasIIITD team, Rohan, Pradyumn, Ramit, @debanjanbhucs, @MADAIguy and @RatnRajiv for getting their paper titled, "SNAP-BATNET: Cascading Author Profiling and Social Network Graphs for Suicide Ideation Detection on Social Media", accepted at @NAACLHLT SRW.
#
# Date:  Sun Mar 17 14:22:04 +0000 2019
# Favorite Count:  15
# Retweet Count:  4
# Number of Images: None
# ------------------------------------------------------------------------------------------------
# Tweet Text:  We have emailed the task details to all shortlisted candidates for @midasIIITD internship. Kindly check the same.
#
# If you are one of the shortlisted candidates and have not received the email then check your SPAM first before approaching.
#
# #MIDAS #Summer #Research #Internship
#
# Date:  Sat Mar 16 14:06:56 +0000 2019
# Favorite Count:  7
# Retweet Count:  0
# Number of Images: None
# ------------------------------------------------------------------------------------------------
# Tweet Text:  IEEE BigMM 2019 - Call for Workshop Proposals.
#
# Contact @midasIIITD @RatnRajiv @debanjanbhucs if you have any query.
#
# Deadlines:
# - Proposals due: April 1, 2019
# - Acceptance notification: April 10, 2019
#
# Further information:
# - Webpage: https://t.co/5XX5Wyxp5T
#
# #IEEE #BigMM19
#
# Date:  Sat Mar 16 09:20:29 +0000 2019
# Favorite Count:  2
# Retweet Count:  1
# Number of Images: None
# ------------------------------------------------------------------------------------------------
# Tweet Text:  Congratulations! Arijit, Ramit, @debanjanbhucs @RatnRajiv for your @NAACLHLT  @naacl SRW 2019 paper, "Speak Up, Fight Back! Detection of Social Media Disclosures of Sexual Harassment".
#
# Check more details at https://t.co/i6eAHg7gcN
#
# #MeToo #Student #Research  #Paper #NAACL
#
# Date:  Sat Mar 16 09:14:58 +0000 2019
# Favorite Count:  7
# Retweet Count:  2
# Number of Images: None
# ------------------------------------------------------------------------------------------------
# Tweet Text:  We will be releasing a very interesting task to shortlisted candidates for the internship at @midasIIITD today. You will be having 10 days to solve the same. You will get a detailed email on the task and submission instruction today. Looking forward to your out of box solution.
#
# Date:  Sat Mar 16 05:13:14 +0000 2019
# Favorite Count:  7
# Retweet Count:  2
# Number of Images: None
# ------------------------------------------------------------------------------------------------
# Retweet Text:  Last day to register for #PortfolioCreationinDesign Workshop Indraprastha Institute of Information Technology, Delhi on 15th March by Ankur Sardana
# Register at - https://t.co/LlO29aGmaE
# #HCDIIITD #workshop https://t.co/EWQ7fuGNDD
#
# Date:  Wed Mar 13 17:09:44 +0000 2019
# Favorite Count:  0
# Retweet Count:  2
# Number of Images:  1
# ------------------------------------------------------------------------------------------------
# Tweet Text:  @ACMMM19 @sigmm @TheOfficialACM @acmmmsys @ACMTVX @ACMICMR @euromm @Benoit_Huet @RatnRajiv @kelkalot
# We need to clearly mention abstract and final submission deadlines at https://t.co/U7DTNNyw87
#
# Currently, we have just mentioned 1st April as the regular paper submission deadline. Kindly update.
#
# #ACMMM19 #Nice #Multimedia https://t.co/ocOCrlFHLH
#
# Date:  Wed Mar 13 04:11:24 +0000 2019
# Favorite Count:  1
# Retweet Count:  0
# Number of Images:  1
# ------------------------------------------------------------------------------------------------
# Retweet Text:  The paper deadline is approaching. 1 April abstract is due. Authors will have until 8 April to upload the final PDF version of their paper submission. For complete submission information, see https://t.co/zKyqPAxErM @sigmm @TheOfficialACM @acmmmsys @ACMTVX @ACMICMR @euromm
#
# Date:  Wed Mar 13 04:06:04 +0000 2019
# Favorite Count:  0
# Retweet Count:  13
# Number of Images: None
# ------------------------------------------------------------------------------------------------
# Retweet Text:  Bookmark this amazing library of image augmentations 😵 by #Kaggle Masters @AlBuslaev @creaf @viglovikov and @cvtalks | https://t.co/7hTShJvbqZ #resources #machinelearning https://t.co/QMOfNmU8dH
#
# Date:  Tue Mar 12 17:43:44 +0000 2019
# Favorite Count:  0
# Retweet Count:  68
# Number of Images:  1
# ------------------------------------------------------------------------------------------------
# Tweet Text:  Awesome members of our @midasIIITD team who are working on Humonics projects. Great to have you on our team.
#
# #team #research #AI #ML #projects https://t.co/lN7hItwPO9
#
# Date:  Tue Mar 12 14:37:55 +0000 2019
# Favorite Count:  16
# Retweet Count:  4
# Number of Images:  1
# ------------------------------------------------------------------------------------------------
# Tweet Text:  @saanidhi @ACMMM19 Before Friday, 15th March.
#
# Date:  Mon Mar 11 14:58:30 +0000 2019
# Favorite Count:  0
# Retweet Count:  0
# Number of Images: None
# ------------------------------------------------------------------------------------------------
# Tweet Text:  We are glad to inform that Adobe is launching Women’s day Tech-Challenge to hire female engineers from 2019 Batch under our #SheCodes initiative.
# Please register here for participating in the challenge at https://t.co/DjkKCJHDBC
#
# Check full details at https://t.co/5ArLu3icva
#
# Date:  Mon Mar 11 12:02:42 +0000 2019
# Favorite Count:  4
# Retweet Count:  0
# Number of Images: None
# ------------------------------------------------------------------------------------------------
# Tweet Text:  We will email tasks to all shortlisted candidates for an internship at @midasIIITD by Friday, 15th March. If you are shortlisted and did not hear from us by that time then kindly drop an email to us.
#
# Looking forward to working with you.
#
# #research #Internship #AI @ACMMM19
#
# Date:  Mon Mar 11 11:54:38 +0000 2019
# Favorite Count:  3
# Retweet Count:  0
# Number of Images: None
# ------------------------------------------------------------------------------------------------
# Tweet Text:  @ACMMM19 @ACM_MM2018 @acmmm17 @sigmm @ACM Less than three weeks are left for @ACMMM19 submission.
# Looking forward to your contribution to #ACMMM and see you in Nice, France.
# @midasIIITD @iiit_hyderabad @iitdelhi @abhinavdhall @iitmadras @iiscbangalore @IITKanpur @iitbombay @iitkharagpur @IITJodhpur @iitropar @IIITDelhi
#
# Date:  Mon Mar 11 06:22:12 +0000 2019
# Favorite Count:  1
# Retweet Count:  1
# Number of Images: None
# ------------------------------------------------------------------------------------------------
# Retweet Text:  Face Recognition using One-Shot Learning – #DeepLearning
# using DL architecture that works great with one-shot learning called Siamese Network.
# https://t.co/Z5oH9vrCns https://t.co/lAubt8vZrM
#
# Date:  Mon Mar 11 06:17:20 +0000 2019
# Favorite Count:  0
# Retweet Count:  64
# Number of Images:  1
# ------------------------------------------------------------------------------------------------
# Tweet Text:  @AvinashSwamina2 @IIITDelhi No. They will be given tasks along with students who will be selected in the second round.
#
# Date:  Fri Mar 08 13:22:07 +0000 2019
# Favorite Count:  1
# Retweet Count:  0
# Number of Images: None
# ------------------------------------------------------------------------------------------------
# Tweet Text:  We are in the process of finalizing the shortlisted candidates for internship at @midasIIITD which we have received in the second round.
# We will assign tasks to all shortlisted candidates around early next week. We are also delaying the task since DTU has mid-sem until 15 March.
#
# Date:  Fri Mar 08 13:15:34 +0000 2019
# Favorite Count:  8
# Retweet Count:  4
# Number of Images: None
# ------------------------------------------------------------------------------------------------
# Tweet Text:  @ylecun @NilayShri @the_dhumketu @debanjanbhucs will it be useful?
#
# Date:  Wed Mar 06 13:44:11 +0000 2019
# Favorite Count:  3
# Retweet Count:  0
# Number of Images: None
# ------------------------------------------------------------------------------------------------
# Retweet Text:  Python Data Science for Beginners https://t.co/yRExdmdZGh https://t.co/vRqTRuayO3
#
# Date:  Wed Mar 06 11:12:30 +0000 2019
# Favorite Count:  0
# Retweet Count:  22
# Number of Images:  1
# ------------------------------------------------------------------------------------------------
# Retweet Text:  Useful feature of our Python stanfordnlp: get lemmas &amp; morphology in many languages. Le ski de fond touché→lemma toucher feats Gender=Masc|Number=Sing|Tense=Past|VerbForm=Part
# ei kerrottaisi→lemma kertoa feats Connegative=Yes|Mood=Cnd|VerbForm=Fin https://t.co/p6MhHyHLC2
#
# Date:  Sun Mar 03 19:36:04 +0000 2019
# Favorite Count:  0
# Retweet Count:  36
# Number of Images: None
# ------------------------------------------------------------------------------------------------
# Tweet Text:  @NilayShri @NilayShri, Certain thing! The next team outing will be for lipreading team.
# Probably, just after @ACMMM19 submission.
#
# Date:  Sun Mar 03 17:09:48 +0000 2019
# Favorite Count:  1
# Retweet Count:  0
# Number of Images: None
# ------------------------------------------------------------------------------------------------
# Tweet Text:  At @midasIIITD, we not only work hard but also have fun.
# Today, we had a team (for Humonics sponsored projects) outing at Pirates of Grill. It was a wonderful day with lots of fun.
#
# #fun #lunch #MIDAS https://t.co/MEVA1NfHRd
#
# Date:  Sun Mar 03 15:37:28 +0000 2019
# Favorite Count:  9
# Retweet Count:  1
# Number of Images:  3
# ------------------------------------------------------------------------------------------------
# Tweet Text:  Considering several requests to extend the deadline for internship application, @midasIIITD at @IIITDelhi has decided that we will open the internship form https://t.co/t54AZ9eo26 again on March 7 and process all application received by March 8, 10 am.
#
# #research #Internship #AI
#
# Date:  Sun Mar 03 14:55:31 +0000 2019
# Favorite Count:  6
# Retweet Count:  2
# Number of Images: None
# ------------------------------------------------------------------------------------------------
# Retweet Text:  39 studies about human perception in 30 minutes by @kennelliott
#
# Awesome article. If you do any visualization or computer vision, these are things you need to know (but most people still don't know!)
# https://t.co/V5aR9a9q2C
#
# Date:  Sun Mar 03 14:26:40 +0000 2019
# Favorite Count:  0
# Retweet Count:  315
# Number of Images: None
# ------------------------------------------------------------------------------------------------
# Tweet Text:  Correction:   @midasIIITD at @IIITDelhi
#
# Date:  Sat Mar 02 17:43:05 +0000 2019
# Favorite Count:  1
# Retweet Count:  0
# Number of Images: None
# ------------------------------------------------------------------------------------------------
# Tweet Text:  Thanks much to all aspirants who have applied for the summer internship 2019 at @midasIIITD at @midasIIITD. We have received over 200 applications. Thus, many good applications are not selected for next round. We have sent emails to all candidates, kindly check that for results.
#
# Date:  Sat Mar 02 09:59:03 +0000 2019
# Favorite Count:  7
# Retweet Count:  1
# Number of Images: None
# ------------------------------------------------------------------------------------------------
# Retweet Text:  Keras Hyperparameter Tuning in Google Colab Using Hyperas https://t.co/hmaI4ukJRX https://t.co/s3nTqqgnAb
#
# Date:  Thu Feb 28 14:21:21 +0000 2019
# Favorite Count:  0
# Retweet Count:  4
# Number of Images:  1
# ------------------------------------------------------------------------------------------------
# Retweet Text:  Great meeting with @midasIIITD alumnus, Sanket Jain today.
# He was among first MTech students who worked with me at @IIITDelhi.
# Currently, he works at @MicrosoftIndia in Bangalore office.
# Best wishes for his career.
# #MIDAS #Alumnus https://t.co/k8oCm8DdgU
#
# Date:  Tue Feb 26 18:30:52 +0000 2019
# Favorite Count:  0
# Retweet Count:  1
# Number of Images:  1
# ------------------------------------------------------------------------------------------------
# Tweet Text:  Correction: They have published the following paper only:
#
# PROMPT: Personalized User Tag Recommendation for Social Media Photos Leveraging Personal and Social Contexts.
#
# Date:  Tue Feb 26 03:40:22 +0000 2019
# Favorite Count:  0
# Retweet Count:  0
# Number of Images: None
# ------------------------------------------------------------------------------------------------
# Tweet Text:  We will process all applications received by March 1, 2019 and notify all shortlisted candidates by March 3.
#
# If you have not applied yet for @midasIIITD internship then you may do so by filling the form https://t.co/t54AZ9eo26
#
# #MIDAS #IIITD #Internship #NLP #ML #AI #DL #CV
#
# Date:  Mon Feb 25 16:10:46 +0000 2019
# Favorite Count:  2
# Retweet Count:  1
# Number of Images: None
# ------------------------------------------------------------------------------------------------
# Retweet Text:  Jit Ghosh discusses the "GloVe" 2014 Stanford paper on word embeddings. This one was a great session! #paperreviewcalls #nlp #deeplearning https://t.co/bLhT8WpwqW
#
# Date:  Sun Feb 24 03:39:40 +0000 2019
# Favorite Count:  0
# Retweet Count:  8
# Number of Images: None
# ------------------------------------------------------------------------------------------------
# Retweet Text:  This CVPR workshop is looking for applications of computer vision in developing countries. You don't need to submit a finished method paper, the workshop is actually seeking ideas for research directions and important problems to solve. https://t.co/jH1VuO3rx4
#
# Date:  Sat Feb 23 15:41:27 +0000 2019
# Favorite Count:  0
# Retweet Count:  90
# Number of Images: None
# ------------------------------------------------------------------------------------------------
# Retweet Text:  PhD Admission 2019 are open now
#
# Online applications starts from 20th February 2019 and the last date to apply is 14th March 2019..
#
# For more details please visit the following link: https://t.co/DwK2DPkSAM
#
# Date:  Fri Feb 22 11:54:49 +0000 2019
# Favorite Count:  0
# Retweet Count:  8
# Number of Images: None
# ------------------------------------------------------------------------------------------------
# Retweet Text:  #AI for Social Good study - how to inform policy, achieve interpretability, reduce bias and more -
# include review of global initiative and UN Goals
# contributions from 16 experts @teamrework https://t.co/KVArhQvbtN https://t.co/5ZQd0M7HPa
#
# Date:  Thu Feb 21 16:27:54 +0000 2019
# Favorite Count:  0
# Retweet Count:  14
# Number of Images:  1
# ------------------------------------------------------------------------------------------------
# Tweet Text:  @IIITDelhi has initiated PhD Admission 2019 process (Regular Round).
#
# Online applications start from 20th February 2019 and the last date to apply is 14th March 2019.
#
# For more details please visit the following link: https://t.co/qWa9I7CFqX.
#
# #IIITD #PhD #Admission
#
# Date:  Thu Feb 21 06:39:27 +0000 2019
# Favorite Count:  2
# Retweet Count:  1
# Number of Images: None
# ------------------------------------------------------------------------------------------------
# Retweet Text:  We tend to focus mainly on creating learning algorithms, and yet there is so much that can be gained from unlearning. In humans, this is one of the main functions of sleep — so here we are ... sleeping neural networks!
#
# https://t.co/YHMe5MmO8w
#
# Date:  Thu Feb 21 04:48:24 +0000 2019
# Favorite Count:  0
# Retweet Count:  13
# Number of Images: None
# ------------------------------------------------------------------------------------------------
# Tweet Text:  @RealAAAI @RatnRajiv Thanks, @RealAAAI for recognizing our efforts.
#
# Congratulations, @midasIIITD students for winning Best Student Poster award at 33rd AAAI Conference on Artificial Intelligence.
#
# Many thanks to authors, Raghav, @the_dhumketu Kshitij, @RatnRajiv @ponguru and Roger.
#
# #AAAI19 #AI https://t.co/oKy1OYCOAR
#
# Date:  Wed Feb 20 07:09:19 +0000 2019
# Favorite Count:  6
# Retweet Count:  3
# Number of Images:  1
# ------------------------------------------------------------------------------------------------
# Tweet Text:  Deepak Gupta, has joined @Google today.
# Earlier this week, Anupam Samanta, has also joined Google.
# Both will be working at Google office in Mount View, California, USA. Having immense pride to see their success.
#
# They have published two papers with @midasIIITD head @RatnRajiv https://t.co/QEiIs5nTSn
#
# Date:  Wed Feb 20 05:38:29 +0000 2019
# Favorite Count:  4
# Retweet Count:  2
# Number of Images:  2
# ------------------------------------------------------------------------------------------------
# Retweet Text:  We are pleased to announce the multimedia Grand Challenges that will be offered at ACM Multimedia in 2019. Check out the list; more info available soon.
# https://t.co/IWN1WK1Vh4
# @sigmm @ACM_MM2018 @acmmm17 @acmmm16 @acm
#
# Date:  Tue Feb 19 17:16:24 +0000 2019
# Favorite Count:  0
# Retweet Count:  15
# Number of Images: None
# ------------------------------------------------------------------------------------------------
# Tweet Text:  In addition to projects related to NLP and Multimedia systems, we have open positions for 3D animation interns too.
# Candidate should have knowledge of Maya character animation, modeling, and good drawing skills.
#
# To apply, fill https://t.co/t54AZ9eo26
# and mention "3D Animation"
#
# Date:  Tue Feb 19 04:29:33 +0000 2019
# Favorite Count:  3
# Retweet Count:  2
# Number of Images: None
# ------------------------------------------------------------------------------------------------
# Retweet Text:  What could the manufacturing industry teach healthcare?
#
# Date:  Tue Feb 19 04:19:05 +0000 2019
# Favorite Count:  0
# Retweet Count:  290
# Number of Images: None
# ------------------------------------------------------------------------------------------------
# Retweet Text:  Dr. Layla El Asri wants you to be able to talk to your machine just like you’d talk to another person. That’s the easy part. Tune in Wednesday to hear how @elasri_layla is getting your machine to understand and talk back to you like a human: #MSRPodcast: https://t.co/SxQB5g1RGh
#
# Date:  Tue Feb 19 04:18:53 +0000 2019
# Favorite Count:  0
# Retweet Count:  21
# Number of Images: None
# ------------------------------------------------------------------------------------------------
# Tweet Text:  To apply for @midasIIITD internship at @IIITDelhi, fill the following form: https://t.co/t54AZ9eo26
#
# Check more details at https://t.co/GvP3wsWtzX
#
# Pls share @debanjanbhucs @RatnRajiv @the_dhumketu @Hitkul_ @NilayShri
#
# #Research #Internship #Multimedia #NLP #ML #DeepLearning
#
# Date:  Mon Feb 18 17:29:44 +0000 2019
# Favorite Count:  11
# Retweet Count:  9
# Number of Images: None
# ------------------------------------------------------------------------------------------------
# Retweet Text:  Digital ag is Cornell’s newest radical collaboration initiative→https://t.co/hVXSnoSbnS
# #DigitalAg #Cornell @CornellNews https://t.co/uxAFPzN5iE
#
# Date:  Mon Feb 18 05:37:59 +0000 2019
# Favorite Count:  0
# Retweet Count:  6
# Number of Images:  1
# ------------------------------------------------------------------------------------------------
# Retweet Text:  Introduction to StanfordNLP: a state-of-the-art NLP library for 53 languages @StanfordNLP #DataScience #NLP #NaturalLanguageProcessing https://t.co/6vxvBat1jS
#
# Date:  Sun Feb 17 17:22:06 +0000 2019
# Favorite Count:  0
# Retweet Count:  51
# Number of Images: None
# ------------------------------------------------------------------------------------------------
# Tweet Text:  Looking forward to your participation in Multimedia Grand Challenges of @ACMMM19
#
# Several interesting challenges are available at https://t.co/mGYxuvrve5
#
# @midasIIITD lab is looking forward to helping students from Indian institutes who plan to participate.
#
# #ACMMM #Multimedia
#
# Date:  Sun Feb 17 09:02:28 +0000 2019
# Favorite Count:  3
# Retweet Count:  1
# Number of Images: None
# ------------------------------------------------------------------------------------------------
# Tweet Text:  Consider attending National Workshop on Intelligent Multimodal Interfaces (NWIMI) at Indian Institute of Technology Jodhpur @IITJodhpur from March 9-10, 2019.
#
# Check more details at https://t.co/lLLzl0dUaI
#
# Date:  Sun Feb 17 08:49:36 +0000 2019
# Favorite Count:  1
# Retweet Count:  0
# Number of Images: None
# ------------------------------------------------------------------------------------------------
# Tweet Text:  Submissions are invited for a special issue of Cognitive Computation (Impact Factor: 3.479) on Affect Recognition in Multimodal Language.
#
# CFP - https://t.co/vP2Naq1C85
#
# Submission deadline - 05/05/2019
#
# Contact @soujanyaporia for further details.
#
# Date:  Sun Feb 17 06:39:30 +0000 2019
# Favorite Count:  1
# Retweet Count:  1
# Number of Images: None
# ------------------------------------------------------------------------------------------------
# Retweet Text:  https://t.co/qNFzJ7ZHki
#
# Date:  Sat Feb 16 16:57:51 +0000 2019
# Favorite Count:  0
# Retweet Count:  1
# Number of Images: None
# ------------------------------------------------------------------------------------------------
# Retweet Text:  Congratulations to Manik Varma, @iitdelhi's Himanshu Jain, Venkatesh Balasubramanian and Bhanu Chunduri for winning the Best Paper Award at #WSDM2019 for their work on SLICE! Discover how extreme classification opens new approaches and unique applications: https://t.co/kAxF6RA2UO https://t.co/yYI43lOYJl
#
# Date:  Fri Feb 15 08:22:23 +0000 2019
# Favorite Count:  0
# Retweet Count:  13
# Number of Images:  1
# ------------------------------------------------------------------------------------------------
# Tweet Text:  Congratulations! Anupam Samanta on joining @Google as a software engineer.
#
# Anupam worked with @midasIIITD head, Dr @RatnRajiv and published two research papers. Great to hear that Anupam got ML and Data Science team in Google due to his research experience and publications. https://t.co/IcuBbjEkjc
#
# Date:  Thu Feb 14 15:56:14 +0000 2019
# Favorite Count:  14
# Retweet Count:  4
# Number of Images:  1
# ------------------------------------------------------------------------------------------------
