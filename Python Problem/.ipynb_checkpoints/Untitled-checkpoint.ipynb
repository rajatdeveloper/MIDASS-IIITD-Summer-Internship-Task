# %%
import tweepy 
import json

# %%
consumer_key = '1Xw6GcjlUD6NIaIHgp31LtC5w'
consumer_secret = 'pPBqHoQuS7hWM1ZB5kHm8IwNOOHEKljWAjKx3rPoDy7ZHffmLc'
access_token_key = '590701052-F14e0oJ0QJRzKeqtPSnxgDHVLr3JPjAdf3X54tY1'
access_token_secret = 'P26vxGuhRBO0k8ZfDL3Rj80F7HVSEuZQWoRFDHxrDZPzo'

# %%
def get_tweets(username): 
    auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
    auth.set_access_token(access_token_key, access_token_secret)
    api = tweepy.API(auth)
    tweets = api.user_timeline(screen_name=username,tweet_mode="extended")
    for tweet in tweets:
        print(tweet.full_text)
        print(tweet.created_at)
        print(tweet.favorite_count)
        print(tweet.retweet_count)
        print("  ")

# %%
get_tweets('midasIIITD')
# Out:
# For anyone interested in submitting to EMNLP 2019, the anonymity period begins in less two weeks, on April 21.
# https://t.co/dOfVWlL55u https://t.co/wwQiFZNuBa
# RT @Harvard: Professor Jelani Nelson founded AddisCoder, a program that teaches students in Ethiopia how to code https://t.co/0sM06p4qxw
# 2019-04-09 05:04:27
# 0
# 33
#
# RT @emnlp2019: For anyone interested in submitting to EMNLP 2019, the anonymity period begins in less two weeks, on April 21.
# https://t.co/…
# 2019-04-09 05:04:11
# 0
# 12
#
# RT @multimediaeval: Announcing the 2019 MediaEval multimedia tasks: https://t.co/V6NMt1vaNV Participation is open for anyone who is interes…
# 2019-04-08 19:38:09
# 0
# 15
#
# Many Congratulations to @midasIIITD student, Shagun Uppal @shagunuppls, on getting selected for the summer internship in the BRAIN lab at Singapore University of Technology &amp; Design @sutdsg, Singapore.
# We wish her the best luck for the internship.
#
# #MIDAS #StudentAchievement https://t.co/snX2GkzvQg
# 2019-04-08 07:08:12
# 13
# 2
#
# @midasIIITD thanks all students who have appeared for the interview yesterday. We will announce the interview results for MIDAS internship latest by 14th April 2019. Sorry for the delay since we are carefully evaluating all applications that we have received for the internship. https://t.co/FANz5vImwU
# 2019-04-08 03:27:42
# 5
# 0
#
# @himanchalchandr Meanwhile, complete CV/NLP task first.
# 2019-04-07 14:17:29
# 0
# 0
#
# @sayangdipto123 Submit as per the guideline again.
# 2019-04-07 14:17:09
# 0
# 0
#
# We request all students whose interview are scheduled today to join at the time given to them and not before or after. We have other interviews scheduled which will be affected.
# Thanks much.
# 2019-04-07 11:43:24
# 1
# 1
#
# Other queries: "none of the Tweeter Apis give the correct count of favorites tested for most of them, all give the wrong count. same is true for retweet. this mostly happens if the no. of likes, retweet is very large. So, what shld be done?"
# Ans: Just use the count given by API.
# 2019-04-07 06:55:19
# 5
# 2
#
# Other queries: "do we have to make two different repositories on Github as "Python Problem" and "CV Problem". Or we have to make a single repository named "root" and upload our code in that?"
# And: Have one repository of any name which has two folders. One python and other cv/nlp
# 2019-04-07 06:53:38
# 4
# 1
#
# Other queries: "If using Twitter api, it does not include any information about images in the response objects sent, so how do we retrieve the image info as requested?"
# Ans: U have to use twitter api or wrappers based on it like tweepy.
# Twitter API does provide image information.
# 2019-04-07 05:32:27
# 6
# 1
#
# Response to some queries asked by students on @midasIIITD task.
# What does the line "dump the responses into JSONlines file" mean?
# It means you have to dump the response into a jsonlines file. jsonlines is a file extension more popularly know as .jsonl
# #MIDAS #Research #Internship
# 2019-04-07 05:29:40
# 7
# 1
#
# RT @kdnuggets: Top 8 #Free Must-Read #Books on #DeepLearning #KDN https://t.co/1DtlN91Yjj
# 2019-04-06 17:11:29
# 0
# 2
#
# @nupur_baghel @PennDATS Congratulation @nupur_baghel on getting admit from @PennDATS.
# She got 5/10 acceptance. She has worked at @midasIIITD on the #kikichallenge problem. We are glad to know that it inspired her to pursue further research. We wish her a great success ahead.
# #MSc #DataScience #UPenn https://t.co/2daLOHGPBU
# 2019-04-06 16:43:27
# 18
# 3
#
# We have emailed the task details to all candidates who have applied to @midasIIITD internship through IIITD portal. Kindly check your spam folder if you have not received the email. We will evaluate all solutions received until April 10 midnight and announce results by April 14.
# 2019-04-05 16:08:37
# 11
# 1
#
# RT @rfpvjr: Our NAACL paper on polarization in language on Twitter surrounding mass shootings is up on arXiv! https://t.co/g7wiegXxDg
# This…
# 2019-04-05 04:05:11
# 0
# 16
#
# RT @kdnuggets: Effective Transfer Learning For NLP https://t.co/Z1m0AzlfVv https://t.co/ccX4Uhxjn8
# 2019-04-05 04:04:43
# 0
# 11
#
# RT @stanfordnlp: What’s new in @Stanford CS224N Natural Language Processing with Deep Learning for 2019? Question answering—1D CNNs—subword…
# 2019-04-03 18:31:53
# 0
# 59
#
# RT @DeepMindAI: Today we're releasing a large-scale extendable dataset of mathematical questions, for training (and evaluating the abilitie…
# 2019-04-03 17:04:32
# 0
# 870
#
# RT @ylecun: Congratulations Jitendra Malik !
#
# Awards are raining on FAIRies these days... https://t.co/1WNcSeQLZe
# 2019-04-03 09:03:40
# 0
# 16
